# %% [markdown]
# ### SVM support vector machine (ml algorithm)
#
#
# help in solving bth classifcation(svc support vector classifier) and regression problem(svr support vector regressor)
# '

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#create synthetic datapoint
from sklearn.datasets import make_classification

# %%
X,y=make_classification(n_samples=100000,n_features=2,n_classes=2,n_clusters_per_class=1,n_redundant=0)

# %%
X
# Out:
# array([[-0.34902552,  1.61233877],
#        [-1.1045221 ,  0.84421656],
#        [ 1.65109099, -0.18660579],
#        ...,
#        [-1.89612502,  1.50509609],
#        [-1.51544393,  1.24692835],
#        [ 1.0167886 ,  0.77021332]], shape=(100000, 2))

# %%
y
# Out:
# array([1, 1, 0, ..., 1, 1, 0], shape=(100000,))

# %%
sns.scatterplot(x=pd.DataFrame(X)[0],y=pd.DataFrame(X)[1],hue=y)
# Out:
# <Axes: xlabel='0', ylabel='1'>

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)

# %%
from sklearn.svm import SVC

# %%
svc=SVC()

# %%
svc.fit(X_train,y_train)
# Out:
# SVC()

# %%
y_pred=svc.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98     15143
#            1       0.99      0.98      0.98     14857
#
#     accuracy                           0.98     30000
#    macro avg       0.98      0.98      0.98     30000
# weighted avg       0.98      0.98      0.98     30000

# %%
rbf=SVC(kernel='rbf')

# %%
rbf.fit(X_train,y_train)
# Out:
# SVC()

# %%
y_pred1=rbf.predict(X_test)

# %%
print(classification_report(y_test,y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98     15143
#            1       0.99      0.98      0.98     14857
#
#     accuracy                           0.98     30000
#    macro avg       0.98      0.98      0.98     30000
# weighted avg       0.98      0.98      0.98     30000
