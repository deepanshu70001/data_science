# %%
pip install gensim
# Out:
# ...
#    ---------------------------------------- 0.0/24.4 MB ? eta -:--:--
#    ------ --------------------------------- 3.9/24.4 MB 21.3 MB/s eta 0:00:01
#    ----------- ---------------------------- 6.8/24.4 MB 17.5 MB/s eta 0:00:02
#    --------------- ------------------------ 9.4/24.4 MB 15.9 MB/s eta 0:00:01
#    -------------------- ------------------- 12.3/24.4 MB 15.1 MB/s eta 0:00:01
#    ------------------------ --------------- 14.9/24.4 MB 14.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 17.8/24.4 MB 14.4 MB/s eta 0:00:01
#    --------------------------------- ------ 20.7/24.4 MB 14.4 MB/s eta 0:00:01
#    -------------------------------------- - 23.6/24.4 MB 14.4 MB/s eta 0:00:01
#    ---------------------------------------- 24.4/24.4 MB 13.9 MB/s  0:00:01
# ...
#
#    ---------------------------------------- 0/2 [smart_open]
#    ---------------------------------------- 0/2 [smart_open]
#    ---------------------------------------- 0/2 [smart_open]
# ...

# %% [markdown]
# ### word to vec
# it is a technique for nlp published in 2013 by google
#
# it uses a neural network to learn word assoctiation from a large corpus of text
#
# once trained it can detect synonamous text or suggest additional word for a partial sentece.

# %%
import gensim
from gensim.models import Word2Vec
from gensim.models import KeyedVectors
import pprint

# %%
import gensim.downloader as api

# %%
wv=api.load('word2vec-google-news-300')
vec_king=wv['king']
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
vec_king
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 vec_king
#
# NameError: name 'vec_king' is not defined

# %%
wv.most_similar("engine")
# Out:
# [('engines', 0.8430763483047485),
#  ('powerplant', 0.6515164375305176),
#  ('V8_engine', 0.6433911323547363),
#  ('Engine', 0.6430367231369019),
#  ('gearbox', 0.613286554813385),
#  ('diesel_engine', 0.612889289855957),
#  ('turbocharger', 0.5878304243087769),
#  ('twin_turbo_engine', 0.5870458483695984),
#  ('Motion_Detection_VMD', 0.5865146517753601),
#  ('turbo', 0.5859070420265198)]

# %%
wv.most_similar('law')
# Out:
# [('laws', 0.739926278591156),
#  ('statute', 0.6761274933815002),
#  ('statutes', 0.6697955131530762),
#  ('Law', 0.6107617616653442),
#  ('legislation', 0.5800460577011108),
#  ('Constitution', 0.5549677610397339),
#  ('constitution', 0.5401366353034973),
#  ('Prevailing_Wage_Act', 0.5384200811386108),
#  ('slayer_statute', 0.5291374921798706),
#  ('rule', 0.5247162580490112)]

# %%
wv.similarity("car","bike")
# Out:
# np.float32(0.58541536)
